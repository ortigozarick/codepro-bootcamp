# %%
print ("Hola mundo")
# Out:
# Hola mundo

# %%
# orden de ejecucion:
fruta = "naranja"
print(fruta)

cantidad_de_frutas = 4
print(cantidad_de_frutas)

fruta = "banana"
print (fruta)
# Out:
# naranja
# 4
# banana

# %%
# Primer challenge

#variables
nombre = "Ricardo"
edad = 40
ciudad = "Lambare"

#impresión
print ("Mi nombre es:", nombre, "   Edad:", edad, "    Mi ciudad:", ciudad)
# Out:
# Mi nombre es: Ricardo    Edad: 40     Mi ciudad: Lambare

# %%
# Segundo challenge

#primeras variables
cantidad_de_manzanas= 59
cantidad_de_naranjas= 48
cantidad_de_frutas= cantidad_de_manzanas + cantidad_de_naranjas
manzanas_vendidas= 50
naranjas_vendidas= 38
Stock_manzanas= cantidad_de_manzanas - manzanas_vendidas
Stock_naranjas= cantidad_de_naranjas - naranjas_vendidas


#impresión
print('Cantidad total de frutas:', cantidad_de_frutas)
print("Manzanas para venta:", cantidad_de_manzanas, "     Manzanas vendidas:", manzanas_vendidas, "    Manzanas en stock:", Stock_manzanas)
print("Naranjas para venta:", cantidad_de_naranjas, "     Naranjas vendidas:", naranjas_vendidas, "    Naranjas en stock:", Stock_naranjas)

#segundas variables
frutas_vendidas= 88
frutas_restantes= cantidad_de_frutas - frutas_vendidas

#impresión
print("Frutas vendidas:", frutas_vendidas,'         Total de frutas restantes:', frutas_restantes)
# Out:
# Cantidad total de frutas: 107
# Manzanas para venta: 59      Manzanas vendidas: 50     Manzanas en stock: 9
# Naranjas para venta: 48      Naranjas vendidas: 38     Naranjas en stock: 10
# Frutas vendidas: 88          Total de frutas restantes: 19

# %%
#Tercer challenge

#variables

nombre= "Victor"
apellido= "Brizuela"

#impresión

print(f"Hola. Me llamo {nombre} {apellido}. Mucho gusto")
# Out:
# Hola. Me llamo Victor Brizuela. Mucho gusto

# %%
#Tercer challenge

#variables

nombre= "Victor"
apellido= "Brizuela"

#impresión

print(f"\n Hola \n Me llamo {nombre} {apellido} \n Un placer")
# Out:
#  Hola
#  Me llamo Victor Brizuela
#  Un placer

# %%
#Cuarto Challenge
#variables

edad_padre= int(input("Ingresar la edad de tu padre:"))
edad_madre= int(input("Ingresar la edad de tu madre:"))
suma_de_edades= edad_padre + edad_madre

#impresiones

print(f"La edad actual de tu Padre es: {edad_padre} anhos. La edad actual de tu madre es: {edad_madre} anhos")
print(f"La suma de las edades de los padres es: {suma_de_edades} anhos")
# Out:
# La edad actual de tu Padre es: 67 anhos. La edad actual de tu madre es: 60 anhos
# La suma de las edades de los padres es: 127 anhos

# %%
#Cuarto challenge

distancia_parque= float(input("Ingresa la distancia total del Parque en Km"))
distancia_recorrida= float(input("Ingresa tu distancia recorrida en Km"))

distancia_faltante= distancia_parque - distancia_recorrida

#Impresiones

print(f'Distancia total del Parque es {distancia_parque} Km')
print(f'Tu distancia total recorrida es {distancia_recorrida} Km')
print(f'Distancia faltante por recorrer {distancia_faltante:.2f} Km')
# Out:
# Distancia total del Parque es 15.5 Km
# Tu distancia total recorrida es 12.3 Km
# Distancia faltante por recorrer 3.20 Km

# %%
#Quinto challenge

def recorrida_parque(): 
    distancia_parque= float(input("Ingresa la distancia total del Parque en Km"))
    distancia_recorrida= float(input("Ingresa tu distancia recorrida en Km"))
    distancia_faltante= distancia_parque - distancia_recorrida

#Impresiones

recorrida_parque()
print(recorrida_parque)
print(distancia_faltante)
# print(f'Distancia total del Parque es {distancia_parque} Km')
# print(f'Tu distancia total recorrida es {distancia_recorrida} Km')
# print(f'Distancia faltante por recorrer {distancia_faltante:.2f} Km')
# Out:
# <function recorrida_parque at 0x000001B8ACF07F60>
# 3.871877549999999

# %%
#Quinto challenge

#variables

distancia_parque= float(input("Ingresa la distancia total del Parque en Km"))
distancia_recorrida= float(input("Ingresa tu distancia recorrida en Km"))
distancia_faltante= distancia_parque - distancia_recorrida

#def

def recorrida_del_parque():
    print(f'Distancia total del Parque es {distancia_parque} Km')
    print(f'Tu distancia total recorrida es {distancia_recorrida} Km')
    print(f'Distancia faltante por recorrer {distancia_faltante:.2f} Km\n')

recorrida_del_parque()
recorrida_del_parque()
recorrida_del_parque()
# Out:
# Distancia total del Parque es 14.28737248365 Km
# Tu distancia total recorrida es 13.37456793246 Km
# Distancia faltante por recorrer 0.91 Km
#
# Distancia total del Parque es 14.28737248365 Km
# Tu distancia total recorrida es 13.37456793246 Km
# Distancia faltante por recorrer 0.91 Km
#
# Distancia total del Parque es 14.28737248365 Km
# Tu distancia total recorrida es 13.37456793246 Km
# Distancia faltante por recorrer 0.91 Km

# %%
#Quinto challenge

#variables

nro_cedula= int(input("Ingresa numero de Cedula"))
monto_seguro_a_pagar= 567500

#def

def recorrida_del_parque():
    print(f'Su numero de cedula es {nro_cedula}')
    print(f'Tu monto a pagar es {monto_seguro_a_pagar}\n')

recorrida_del_parque()
recorrida_del_parque()
recorrida_del_parque()
# Out:
# Su numero de cedula es 4072478
# Tu monto a pagar es 567500
#
# Su numero de cedula es 4072478
# Tu monto a pagar es 567500
#
# Su numero de cedula es 4072478
# Tu monto a pagar es 567500

# %%
ruta1= 137
ruta2= 89

total_km= ruta1 + ruta2

def

# %%
#Sexto challenge

#variables

nombre_elemento= input("Ingrese nombre del producto")
altura= float(input("Ingrese la altura del producto en cm"))
ancho= float(input("Ingrese el ancho del producto en cm"))
peso= int(input("Ingrese el peso del producto en Kg"))
color= input("Ingrese el color del producto")

#definición

def detalles_del_producto():
    print(f"El nombre del producto es {nombre_elemento}")
    print(f"La altura del producto es {altura}")
    print(f"El ancho del producto es {ancho}")
    print(f"El peso del producto es {peso} kg")
    print(f"El color del producto es {color}\n")

#LLamada de función

detalles_del_producto()
detalles_del_producto()
detalles_del_producto()

# %%
#Sexto challenge

#variables

nombre_elemento= input("Ingrese la marca de su televisor")
pulgadas= input("Ingrese la pulgadas del producto que desee")
tipo_de_tv= input("Ingrese el tipo tecnologia del panel Led, Qled, Oled")
forma_de_pago= input("Ingrese su forma de pago - Contado o Cuotas")

#definición

def detalles_del_producto():
    print (f"El televisor que deseas es {nombre_elemento}, de pulgadas {pulgadas} y tipo {tipo_de_tv}")
    print (f"Forma de pago {forma_de_pago}\n")
           
#LLamada de función

detalles_del_producto()
detalles_del_producto()
detalles_del_producto()
# Out:
# El televisor que deseas es jhgfhf, de pulgadas 90 y tipo qled
# Forma de pago contado
#
# El televisor que deseas es jhgfhf, de pulgadas 90 y tipo qled
# Forma de pago contado
#
# El televisor que deseas es jhgfhf, de pulgadas 90 y tipo qled
# Forma de pago contado

# %%
#Septimo challenge

#variables

nombre_elemento= input("Ingrese nombre del producto")
tipo= (input("Ingrese el tipo de producto - Qled, Led, Oled"))
altura= int(input("Ingrese en cm la altura del producto"))
ancho= int(input("Ingrese en cm el ancho del producto"))
color= input("Ingrese el color del producto")

#def

def detalles_del_producto():
    print(f"El nombre del producto es {nombre_elemento}")

    print(f"El tipo de producto es {tipo}")
    print(f"El tamanho del producto es {altura} cm de alto")
    print(f"El tamanho del producto es {ancho} cm de ancho")
    print(f"El color del producto es {color}\n")


#LLamada de función

detalles_del_producto()
detalles_del_producto()
detalles_del_producto()
# Out:
# El nombre del producto es samsung
# El tipo de producto es qled
# El tamanho del producto es 170 cm de alto
# El tamanho del producto es 50 cm de ancho
# El color del producto es negro
#
# El nombre del producto es samsung
# El tipo de producto es qled
# El tamanho del producto es 170 cm de alto
# El tamanho del producto es 50 cm de ancho
# El color del producto es negro
#
# El nombre del producto es samsung
# El tipo de producto es qled
# El tamanho del producto es 170 cm de alto
# El tamanho del producto es 50 cm de ancho
# El color del producto es negro
