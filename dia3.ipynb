# %%
print("Hola")
# Out:
# Hola

# %%
def saludar():
    print("Hola")
saludar()
# Out:
# Hola

# %%
# Crear una función que imprima la variable palabra

#1ro (Definir la variable palabra)
#2do (Crear una función def "imprimir_palabra")
#3ro (Imprimir la variable palabra)
#4to (Llamar a la función)

palabra="Hola"
def imprimir_palabra():
    print(palabra)

imprimir_palabra()
# Out:
# Hola

# %%
#Sumar dos numeros

#1ro Definir dos variables con int(input()) o float(input()), numero1 y numero 2 fuera de la función def
#2do Definir la función sumar(n1, n2)
#3ro Dos opciones 1-   n3=n1+n2    2-    print(n1+n2)
#4to LLamar a la función sumar()

# %%
numero1= int(input("Ingresa un numero"))
numero2= int(input("Ingresa otro numero"))

def sumar(n1, n2):
    n3= n1+n2
    print(n3)

sumar(numero1, numero2)
# Out:
# 25

# %%
numero1= int(input("Ingresa un numero"))
numero2= int(input("Ingresa otro numero"))

def sumar(n1, n2):

    print(n1+n2)

sumar(numero1, numero2)
# Out:
# 25

# %%
# Crear una función que reciba dos letras (parametros) y que verifique si son iguales
# Si son iguales imprimir son iguales
# Si son diferentes imprimir son diferentes

letra1= input("Ingrese primera letra")
letra2= input("Ingrese segunda letra")

print(f"Las letras ingresadas son", letra1,"y", letra2)

def verificar_letra(l1, l2):
    if l1==l2:
        print("Letra son iguales")
    else:
        print("Son diferentes")

verificar_letra(letra1, letra2)
# Out:
# Las letras ingresadas son a y g
# Son diferentes

# %%
# return 

def sumar(n1, n2):
    resultado_suma= n1+n2
    print(resultado_suma)

sumar(2, 2)
# Out:
# 4

# %%
parametro1= input("Ingrese una palabra")
parametro2= int(input("Ingrese cantidad"))

print (f"La palabra ingresada es ", parametro1)
print (f"El numero ingresado es ", parametro2)

def comparar(palabra, cantidad):
    if len(palabra) == cantidad:
        return f"La palabra contiene la cantidad igual a el nro ingresado", True
    else:
        return f"La cantidad no es similar", False


comparar(parametro1, parametro2)
# Out:
# La palabra ingresada es  inexperto
# El numero ingresado es  7
# ('La cantidad no es similar', False)

# %%
s

# %%
palabra_ingresada= input("Ingrese una palabra")
letra_seleccionada= input("Ingrese letra")

print (f"La palabra ingresada es", palabra_ingresada)
print (f"La letra a buscar es", letra_seleccionada)

def buscar(palabra, letra):
    if letra in palabra:
        return f"La palabra es, {palabra}, Y la letra encontrada es, [{letra}]"
    else:
        return f"La letra no existe en la palabra ingresada", letra


buscar(palabra_ingresada, letra_seleccionada)
# Out:
# La palabra ingresada es hola
# La letra a buscar es q
# ('La letra no existe en la palabra ingresada', 'q')

# %%
palabra_a_encontrar= input("Ingresa una palabra")
print(f"Esta es la palabra a encontra{palabra_a_encontrar}")

palabra_secreta= input("Ingrese palabra secreta")
print(f"Esta es la palabra secreta{palabra_secreta}")

lista_de_palabras= list(palabra_a_encontrar)
print(f"Lista {lista_de_palabras}")

# %%
#Pedir al usuario que ingrese 1 palabra luego convertir esa palabra en una lista con sus caracteres con list()
# agregar esa lista de caracteres a una lista llamada palabras_ingresadas. repetir el proceso 3 veces
# cada vez que se agregue una lista de caracteres, imprimir la lista palabras_ingresadas

palabras_ingresadas=[]

palabra1= input("Ingrese una palabra")
print(f"La 1ra palabra ingresada es: {palabra1}")
list(palabra1)
print(list(palabra1))
palabra2= input("Ingrese 2da palabra")
print(f"La 2da palabra ingresada es: {palabra2}")

# %%
#lista=[['h','o','l','i','s'],['h','e','l','l','o'],['h','a','l','l','o']]
#print (lista)

lista1=("holis")
lista2=("hello")
lista3=("hallo")

list(lista1)
list(lista2)
list(lista3)

listas=(list(lista1),list(lista2),list(lista3))
list(listas)
print(list(listas))

def imprimir(lista123):
    print(lista123[0])
    print(lista123[1])
    print(lista123[2])

imprimir(listas)
# Out:
# [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']

# %%
#Funcion_Verificadora:

letras_verificadas = []
cantidad_letras = 5

def verificador_palabra(palabra_ingresada, palabra_secreta):
    for i in range(cantidad_letras):
        las_palabras_son_iguales = palabra_ingresada[i] == palabra_secreta[i] # True o False
        la_letra_existe_en_la_palabra = palabra_ingresada[i] in palabra_secreta 
        
        if las_palabras_son_iguales:
            letras_verificadas.append(f"[{palabra_ingresada[i]}]")
        elif la_letra_existe_en_la_palabra:
            letras_verificadas.append(f"({palabra_ingresada[i]})")
        else:
            letras_verificadas.append(palabra_ingresada[i])
    
    return letras_verificadas

verificador_palabra('holas', 'calor')
# Out:
# ['h', '(o)', '[l]', '(a)', 's']

# %%
# definir la cantidad de intentos = variable
intentos = 0

while intentos < 6:
    print(f"te quedan {6 - intentos} intentos")
    intentos = intentos + 1
    palabra_ingresada = input("Ingrese una palabra")
    print(f"la palabra ingresada es: {palabra_ingresada}")
